# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="white", color_codes=True)

# %%
#Exploring the data
file = pd.read_csv("C:/datasets/heart.csv")

# %%
file.info() #displaying the information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
file.shape
# Out:
# (918, 12)

# %%
file.shape #return no of rows and columns in the csv file
# Out:
# (918, 12)

# %%
file.describe() #summary of the given set
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
file.dtypes.to_frame() #to identify the different types of data types
# Out:
#                       0
# Age               int64
# Sex              object
# ChestPainType    object
# RestingBP         int64
# Cholesterol       int64
# FastingBS         int64
# RestingECG       object
# MaxHR             int64
# ExerciseAngina   object
# Oldpeak         float64
# ST_Slope         object
# HeartDisease      int64

# %%
file.isnull().sum().to_frame() #To check whether the null values present in the dataset or not
# Out:
#                 0
# Age             0
# Sex             0
# ChestPainType   0
# RestingBP       0
# Cholesterol     0
# FastingBS       0
# RestingECG      0
# MaxHR           0
# ExerciseAngina  0
# Oldpeak         0
# ST_Slope        0
# HeartDisease    0

# %%
file.head() #fewer data's from the top
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
file.tail() #fewer data's from the bottom
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
file.mean()
# Out:
# Age              53.510893
# RestingBP       132.396514
# Cholesterol     198.799564
# FastingBS         0.233115
# MaxHR           136.809368
# Oldpeak           0.887364
# HeartDisease      0.553377
# dtype: float64

# %%
file.min()
file.median()
file.max()
# Out:
# Age                77
# Sex                 M
# ChestPainType      TA
# RestingBP         200
# Cholesterol       603
# FastingBS           1
# RestingECG         ST
# MaxHR             202
# ExerciseAngina      Y
# Oldpeak           6.2
# ST_Slope           Up
# HeartDisease        1
# dtype: object

# %%
file.duplicated().sum()
# Out:
# 0

# %%
file.Cholesterol.value_counts()
# Out:
# 0      172
# 254     11
# 223     10
# 220     10
# 230      9
#       ...
# 392      1
# 316      1
# 153      1
# 466      1
# 131      1
# Name: Cholesterol, Length: 222, dtype: int64

# %%
file["Age"].value_counts()
# Out:
# 54    51
# 58    42
# 55    41
# 56    38
# 57    38
# 52    36
# 51    35
# 59    35
# 62    35
# 53    33
# 60    32
# 48    31
# 61    31
# 63    30
# 50    25
# 46    24
# 41    24
# 43    24
# 64    22
# 65    21
# 49    21
# 47    19
# 44    19
# 42    18
# 45    18
# 38    16
# 67    15
# 39    15
# 66    13
# 69    13
# 40    13
# 35    11
# 37    11
# 68    10
# 34     7
# 74     7
# 70     7
# 36     6
# 71     5
# 32     5
# 72     4
# 29     3
# 75     3
# 33     2
# 77     2
# 76     2
# 31     2
# 30     1
# 28     1
# 73     1
# Name: Age, dtype: int64

# %%
file["Cholesterol"].value_counts()
# Out:
# 0      172
# 254     11
# 223     10
# 220     10
# 230      9
#       ...
# 392      1
# 316      1
# 153      1
# 466      1
# 131      1
# Name: Cholesterol, Length: 222, dtype: int64

# %%
file.groupby('Cholesterol')['Age'].describe()
# Out:
#              count       mean       std   min    25%   50%   75%   max
# Cholesterol
# 0            172.0  56.238372  8.616327  32.0  51.75  57.5  62.0  74.0
# 85             1.0  56.000000       NaN  56.0  56.00  56.0  56.0  56.0
# 100            2.0  54.000000  2.828427  52.0  53.00  54.0  55.0  56.0
# 110            1.0  69.000000       NaN  69.0  69.00  69.0  69.0  69.0
# 113            1.0  76.000000       NaN  76.0  76.00  76.0  76.0  76.0
# ...            ...        ...       ...   ...    ...   ...   ...   ...
# 491            1.0  44.000000       NaN  44.0  44.00  44.0  44.0  44.0
# 518            1.0  53.000000       NaN  53.0  53.00  53.0  53.0  53.0
# 529            1.0  32.000000       NaN  32.0  32.00  32.0  32.0  32.0
# 564            1.0  67.000000       NaN  67.0  67.00  67.0  67.0  67.0
# 603            1.0  54.000000       NaN  54.0  54.00  54.0  54.0  54.0
#
# [222 rows x 8 columns]

# %%
file.plot(kind="scatter",x="Cholesterol",y="Age")
plt.grid()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = pd.read_csv("C:/datasets/heart.csv")
file.plot(kind="scatter",x="RestingBP",y="Age")
# Out:
# <AxesSubplot:xlabel='RestingBP', ylabel='Age'>

# %%
file=pd.read_csv("C:/datasets/heart.csv")
file
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
file["ChestPainType"] = file["ChestPainType"].map({"TA":1, "ATA":2, "NAP":3,"ASY":4})
file.head()
# Out:
#    Age Sex  ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0   40   M              2        140          289          0     Normal
# 1   49   F              3        160          180          0     Normal
# 2   37   M              2        130          283          0         ST
# 3   48   F              4        138          214          0     Normal
# 4   54   M              3        150          195          0     Normal
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
# Resting ECG

file["RestingECG"] = file['RestingECG'].map({"Normal":1,"ST":2, "LVH":3 })
file.head()
# Out:
#    Age Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40   M              2        140          289          0           1
# 1   49   F              3        160          180          0           1
# 2   37   M              2        130          283          0           2
# 3   48   F              4        138          214          0           1
# 4   54   M              3        150          195          0           1
#
#    MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0    172              N      0.0       Up             0
# 1    156              N      1.0     Flat             1
# 2     98              N      0.0       Up             0
# 3    108              Y      1.5     Flat             1
# 4    122              N      0.0       Up             0

# %%
# ST Slope
file["ST_Slope"] = file['ST_Slope'].map({"Up":1, "Flat":2, "Down": 3}  )
file.head()
# Out:
#    Age Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40   M              2        140          289          0           1
# 1   49   F              3        160          180          0           1
# 2   37   M              2        130          283          0           2
# 3   48   F              4        138          214          0           1
# 4   54   M              3        150          195          0           1
#
#    MaxHR ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172              N      0.0         1             0
# 1    156              N      1.0         2             1
# 2     98              N      0.0         1             0
# 3    108              Y      1.5         2             1
# 4    122              N      0.0         1             0

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    int64
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int64
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int64
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(9), object(2)
# memory usage: 86.2+ KB

# %%
file.Cholesterol.value_counts()
# Out:
# 0      172
# 254     11
# 223     10
# 220     10
# 230      9
#       ...
# 392      1
# 316      1
# 153      1
# 466      1
# 131      1
# Name: Cholesterol, Length: 222, dtype: int64

# %%
file.groupby('HeartDisease')['Age'].describe()
# Out:
#               count       mean       std   min   25%   50%   75%   max
# HeartDisease
# 0             410.0  50.551220  9.444915  28.0  43.0  51.0  57.0  76.0
# 1             508.0  55.899606  8.727056  31.0  51.0  57.0  62.0  77.0

# %%
plt.figure(figsize=(10, 7))
plt.hist(file.Age, histtype='bar')
plt.title("Age")
plt.show()

# %%
file.groupby('HeartDisease')['RestingECG'].describe()
# Out:
#              count unique     top freq
# HeartDisease
# 0              410      3  Normal  267
# 1              508      3  Normal  285

# %%
plt.figure(figsize=(10, 7))
plt.hist(file.Sex, histtype='bar')
plt.title('Cholesterol')
plt.show()

# %%
file.groupby('HeartDisease')['MaxHR'].describe()
# Out:
#               count        mean        std   min    25%    50%     75%    max
# HeartDisease
# 0             410.0  148.151220  23.288067  69.0  134.0  150.0  165.00  202.0
# 1             508.0  127.655512  23.386923  60.0  112.0  126.0  144.25  195.0

# %%
plt.figure(figsize=(10, 7))
plt.hist(file.Sex, histtype='bar')
plt.title('MaxHR')
plt.show()

# %%
plt.figure(figsize=(10,11))
sns.heatmap(file.corr(),annot=True)
plt.plot()
# Out:
# []

# %%
sns.FacetGrid(file, hue="HeartDisease", palette="husl", size=5) \
   .map(plt.scatter, "Age", "Cholesterol") \
   .add_legend()

# %%
sns.pairplot(file, hue="HeartDisease", palette="husl", size=3)  #pair plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import matplotlib.cm as cm

# %%
data = pd.read_csv("C:/Users/Pooja Devi/Desktop/Semester 5/PythonML/Dataset.csv")

# %%
print(f'data length: {len(data)}\n')
print(f'missing values by column:\n{data.isnull().sum()}\n')
print(f'data duplication(all columns): {data.duplicated().sum()}')
# Out:
# data length: 918
#
# missing values by column:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64
#
# data duplication(all columns): 0

# %%
def value_counts_plot_bar(df, column, fontsize=15):
    label_counts = df[column].value_counts()
    
    plt.figure(figsize=(15,10))
    plt.style.use('seaborn')
    bar_colors = cm.rainbow(np.linspace(0,1,len(df[column].unique())))
    plt.bar(label_counts.index.values,
            label_counts.values,
            color=bar_colors,
            linewidth=0,
            alpha=0.6)
    plt.tick_params(labelsize=fontsize)
    plt.xlabel(column, fontsize=fontsize)
    plt.ylabel(f'{column} value counts', fontsize=fontsize)
    plt.show()
    
def value_counts_plot_line(df, column, fontsize=15):
    plt.figure(figsize=(15,10))
    plt.style.use('seaborn')
    df[column].value_counts().sort_index().plot(
        color='orangered', 
        linewidth=4
    )
    plt.tick_params(labelsize=fontsize)
    plt.xlabel(column, fontsize=fontsize)
    plt.ylabel(f'{column} value counts', fontsize=fontsize)
    plt.show()

def plot_bar_by_gender(df, column, fontsize=15, bar_width=0.6):
    plt.figure(figsize=(15,10))
    plt.style.use('seaborn')
    bar_colors = cm.rainbow(np.linspace(0,1,len(df['Sex'].unique())))

    for bar_color, (key, df_by_key) in zip(bar_colors, df.groupby('Sex')):
        df_index = df_by_key[column].value_counts().index
        df_values = df_by_key[column].value_counts().values
        set_align = 'edge' if key is 'M' else 'center'
        plt.bar(
            df_index, 
            df_values,
            width=bar_width,
            linewidth=0, 
            color=bar_color, 
            label=key, 
            alpha=0.6,
            align=set_align
        )
        plt.legend(title='Sex', fontsize=fontsize)
        plt.tick_params(labelsize=fontsize)
        plt.xticks(df[column].unique())
        plt.xlabel(column, fontsize=fontsize)
        plt.ylabel(f'{column} value counts', fontsize=fontsize)
    plt.show()
    
def plot_line_by_gender(df, column, fontsize=15):
    plt.figure(figsize=(15,10))
    plt.style.use('seaborn')
    line_colors = cm.rainbow(np.linspace(0,1,len(df['Sex'].unique())))
    
    for line_color, (key, df_by_key) in zip(line_colors, df.groupby('Sex')):
        
        df_by_key[column].value_counts().sort_index().plot(
            color=line_color,
            label=key,
            linewidth=4
        )
        plt.legend(title='Sex', fontsize=fontsize)
        plt.tick_params(labelsize=fontsize)
        plt.xlabel(column, fontsize=fontsize)
        plt.ylabel(f'{column} value counts', fontsize=fontsize)
    plt.show()
# Out:
# <>:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\POOJAD~1\AppData\Local\Temp/ipykernel_16812/2799647838.py:37: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   set_align = 'edge' if key is 'M' else 'center'

# %%
value_counts_plot_line(data, 'Age')

# %%
value_counts_plot_bar(data, 'Sex')

# %%
value_counts_plot_bar(data, 'ChestPainType')

# %%
value_counts_plot_line(data, 'RestingBP')

# %%
value_counts_plot_line(data, 'Cholesterol')

# %%
value_counts_plot_bar(data, 'FastingBS')

# %%
value_counts_plot_bar(data, 'RestingECG')

# %%
value_counts_plot_bar(data, 'HeartDisease')

# %%
plot_line_by_gender(data, 'Age')

# %%
plot_bar_by_gender(data, 'ChestPainType')

# %%
plot_line_by_gender(data, 'RestingBP')

# %%
plot_line_by_gender(data, 'Cholesterol')

# %%
plot_bar_by_gender(data, 'FastingBS')

# %%
plot_bar_by_gender(data, 'RestingECG')

# %%
plot_bar_by_gender(data, 'HeartDisease')

# %%
#PREPROCESS

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
def categorical_encoder(df):
    new_df = df.copy()
    le = LabelEncoder()
    new_df['Sex'] = le.fit_transform(new_df['Sex'].values)
    new_df['ChestPainType'] = le.fit_transform(new_df['ChestPainType'].values)
    new_df['RestingECG'] = le.fit_transform(new_df['RestingECG'].values)
    new_df['ExerciseAngina'] = le.fit_transform(new_df['ExerciseAngina'].values)
    new_df['ST_Slope'] = le.fit_transform(new_df['ST_Slope'].values)
    return new_df

def feature_scaler(df):
    new_df = df.copy()
    sc = StandardScaler()
    # standardize on including some category columns as well
    new_df['Sex'] = sc.fit_transform(new_df['Sex'].values.reshape(-1, 1))
    new_df['RestingBP'] = sc.fit_transform(new_df['RestingBP'].values.reshape(-1, 1))
    new_df['Cholesterol'] = sc.fit_transform(new_df['Cholesterol'].values.reshape(-1, 1))
    new_df['FastingBS'] = sc.fit_transform(new_df['FastingBS'].values.reshape(-1, 1))
    new_df['RestingECG'] = sc.fit_transform(new_df['RestingECG'].values.reshape(-1, 1))
    new_df['MaxHR'] = sc.fit_transform(new_df['MaxHR'].values.reshape(-1, 1))
    new_df['Oldpeak'] = sc.fit_transform(new_df['Oldpeak'].values.reshape(-1, 1))  
    return new_df

data = categorical_encoder(data) 
data = feature_scaler(data)

# %%
data.head()
# Out:
#    Age       Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0   40  0.515952              1   0.410909     0.825070  -0.551341
# 1   49 -1.938163              2   1.491752    -0.171961  -0.551341
# 2   37  0.515952              1  -0.129513     0.770188  -0.551341
# 3   48 -1.938163              0   0.302825     0.139040  -0.551341
# 4   54  0.515952              2   0.951331    -0.034755  -0.551341
#
#    RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# 0    0.017255  1.382928               0 -0.832432         2             0
# 1    0.017255  0.754157               0  0.105664         1             1
# 2    1.601219 -1.525138               0 -0.832432         2             0
# 3    0.017255 -1.132156               1  0.574711         1             1
# 4    0.017255 -0.581981               0 -0.832432         2             0

# %%
data.tail()
# Out:
#      Age       Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 913   45  0.515952              3  -1.210356     0.596393  -0.551341
# 914   68  0.515952              0   0.627078    -0.053049   1.813758
# 915   57  0.515952              0  -0.129513    -0.620168  -0.551341
# 916   57 -1.938163              1  -0.129513     0.340275  -0.551341
# 917   38  0.515952              2   0.302825    -0.217696  -0.551341
#
#      RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease
# 913    0.017255 -0.188999               0  0.293283         1             1
# 914    0.017255  0.164684               0  2.357094         1             1
# 915    0.017255 -0.857069               1  0.293283         1             1
# 916   -1.566710  1.461525               0 -0.832432         1             1
# 917    0.017255  1.422226               0 -0.832432         2             0

# %%
def feature_engineering(df):
    new_df = df.copy()
    # apply to standardized columns
    columns = ['Sex','RestingBP','Cholesterol','FastingBS','RestingECG','MaxHR','Oldpeak']
    new_df['standardized_columns_mean'] = new_df[columns].mean(axis=1)
    return new_df

data = feature_engineering(data)

# %%
data.head()
# Out:
#    Age       Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0   40  0.515952              1   0.410909     0.825070  -0.551341
# 1   49 -1.938163              2   1.491752    -0.171961  -0.551341
# 2   37  0.515952              1  -0.129513     0.770188  -0.551341
# 3   48 -1.938163              0   0.302825     0.139040  -0.551341
# 4   54  0.515952              2   0.951331    -0.034755  -0.551341
#
#    RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope  HeartDisease  \
# 0    0.017255  1.382928               0 -0.832432         2             0
# 1    0.017255  0.754157               0  0.105664         1             1
# 2    1.601219 -1.525138               0 -0.832432         2             0
# 3    0.017255 -1.132156               1  0.574711         1             1
# 4    0.017255 -0.581981               0 -0.832432         2             0
#
#    standardized_columns_mean
# 0                   0.252620
# 1                  -0.041805
# 2                  -0.021581
# 3                  -0.369690
# 4                  -0.073710

# %%
# !pip install pytorch-lightning==1.4.5 -q

# %%
import gc
import warnings
import multiprocessing
from sklearn.cluster import KMeans
from sklearn.metrics import roc_auc_score
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import pytorch_lightning as pl
from pytorch_lightning.utilities.seed import seed_everything


warnings.filterwarnings('ignore')

# %%
class Cfg:
    seed = 42
    lr = 3e-3 
    epochs = 100
    n_folds = 5
    train_batch_size = 32
    val_batch_size = 512
    input_size = len(data.columns) - 1
    hidden_size = 256
    dropout_ratio = 0.1
    num_classes = 2
    target_name = 'HeartDisease'
    n_gpus = torch.cuda.device_count()
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
seed_everything(Cfg.seed, workers=True)
# Out:
# Global seed set to 42
# 42

# %%
class HeartFailureDataset(Dataset):
    def __init__(self, data):
        super().__init__()
        self.data = data
        
        self.prepare_data()
        
    def __len__(self):
        return len(self.data)
    
    def prepare_data(self):
        self.labels = np.array(self.data['HeartDisease'].values.tolist())
        self.inputs = np.array(self.data.drop('HeartDisease',axis=1).values.tolist())
    
    def __getitem__(self, index):
        return {
            'inputs': torch.tensor(self.inputs[index], dtype=torch.float),
            'labels': torch.tensor(self.labels[index], dtype=torch.long)
        }

# %%
class TanhExp(nn.Module):
    '''
    TanhExp: https://arxiv.org/abs/2003.09855  
    '''
    def __init__(self):
        super().__init__()

    @torch.jit.script
    def tanhexp(x):
        return x * torch.tanh(torch.exp(x))

    def forward(self, input):
        output = self.tanhexp(input)
        return output

# %%
class CustomModel(pl.LightningModule):
    def __init__(self, config):
        super().__init__()
        self.config = config
        
        self.mlp = nn.Sequential(
            nn.utils.weight_norm(
                nn.Linear(self.config.input_size, self.config.hidden_size)
            ),
            TanhExp(),
            nn.utils.weight_norm(
                nn.Linear(self.config.hidden_size, self.config.hidden_size)
            ),
            TanhExp(),
            nn.utils.weight_norm(
                nn.Linear(self.config.hidden_size, self.config.hidden_size)
            ),
            TanhExp(),
            nn.AlphaDropout(self.config.dropout_ratio),
            nn.Linear(self.config.hidden_size, self.config.num_classes)
        )
        self.criterion = nn.CrossEntropyLoss()
        
    def forward(self, inputs, labels=None):
        preds = self.mlp(inputs)
        if labels is not None:
            loss = self.criterion(preds, labels)
            return loss
        else:
            return preds
        
    def training_step(self, batch, batch_idx):
        loss = self.forward(inputs=batch['inputs'], 
                          labels=batch['labels'])
        self.log('train_loss', loss)
        return loss
    
    def validation_step(self, batch, batch_idx):
        val_loss = self.forward(inputs=batch['inputs'], 
                              labels=batch['labels'])
        self.log('val_loss', val_loss)
        return val_loss
    
    def test_step(self, batch, batch_idx):
        return self.validation_step(batch, batch_idx)
    
    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.config.lr)

# %%
def inference(model, data_loader, config):
    all_outputs = []
    all_labels = []
    
    for batch_idx, batch in enumerate(data_loader):
        inputs = batch['inputs']
        labels = batch['labels']
        
        inputs = inputs.to(config.device)
        labels = labels.to(config.device)
        
        model.to(config.device)
        model.eval()
        with torch.no_grad():
            outputs = model(
                inputs=inputs, 
                labels=None
                )
        outputs = outputs.cpu().detach().numpy()[:,1].tolist()
        labels = labels.cpu().detach().numpy().tolist() 
        all_outputs.extend(outputs)
        all_labels.extend(labels)
    
    return all_outputs, all_labels

# %%
def run_train(fold, data, tr_idx, val_idx, config):
    print(f'     ----- Fold: {fold} -----')
    data = data.drop('cluster_id', axis=1)
    train, val = data.iloc[tr_idx], data.iloc[val_idx]
    
    train_ds = HeartFailureDataset(train)
    val_ds = HeartFailureDataset(val)
    
    train_loader = DataLoader(train_ds, 
                              batch_size=config.train_batch_size, 
                              num_workers=multiprocessing.cpu_count(), 
                              pin_memory=True, 
                              drop_last=True,
                              shuffle=True)
    
    val_loader = DataLoader(val_ds, 
                            batch_size=config.val_batch_size, 
                            num_workers=multiprocessing.cpu_count(), 
                            pin_memory=True, 
                            drop_last=False,
                            shuffle=False)
    checkpoint = pl.callbacks.ModelCheckpoint(monitor='val_loss', 
                                              mode='min', 
                                              save_top_k=1,  
                                              save_weights_only=True, 
                                              dirpath=f'model_fold{fold}/')
    
    tb_logger = pl.loggers.TensorBoardLogger(f'model_fold{fold}_logs/')

    trainer = pl.Trainer(max_epochs=config.epochs,
                         gpus=config.n_gpus,
                         logger=tb_logger,
                         callbacks=[checkpoint],
                         progress_bar_refresh_rate=0)
    model = CustomModel(config)
    model.to(config.device)
    trainer.fit(model, train_loader, val_loader)
    
    model.load_state_dict(torch.load(checkpoint.best_model_path)['state_dict'])
    outputs, labels = inference(model, val_loader, config)

    del train_ds, val_ds, train_loader, val_loader, model
    gc.collect()
    torch.cuda.empty_cache()

    return outputs, labels

# %%
from sklearn.model_selection._split import _BaseKFold, _RepeatedSplits
from sklearn.utils.validation import check_random_state, column_or_1d
from sklearn.utils.multiclass import type_of_target
from collections import defaultdict

# %%
class StratifiedGroupKFold(_BaseKFold):
    def __init__(self, n_splits=5, shuffle=False, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle,
                         random_state=random_state)

    def _iter_test_indices(self, X, y, groups):
        rng = check_random_state(self.random_state)
        y = np.asarray(y)
        type_of_target_y = type_of_target(y)
        allowed_target_types = ('binary', 'multiclass')
        if type_of_target_y not in allowed_target_types:
            raise ValueError(
                'Supported target types are: {}. Got {!r} instead.'.format(
                    allowed_target_types, type_of_target_y))

        y = column_or_1d(y)
        _, y_inv, y_cnt = np.unique(y, return_inverse=True, return_counts=True)
        if np.all(self.n_splits > y_cnt):
            raise ValueError("n_splits=%d cannot be greater than the"
                             " number of members in each class."
                             % (self.n_splits))
        n_smallest_class = np.min(y_cnt)
        if self.n_splits > n_smallest_class:
            warnings.warn(("The least populated class in y has only %d"
                           " members, which is less than n_splits=%d."
                           % (n_smallest_class, self.n_splits)), UserWarning)
        n_classes = len(y_cnt)
        _, groups_inv, groups_cnt = np.unique(
            groups, return_inverse=True, return_counts=True)
        y_counts_per_group = np.zeros((len(groups_cnt), n_classes))
        for class_idx, group_idx in zip(y_inv, groups_inv):
            y_counts_per_group[group_idx, class_idx] += 1

        y_counts_per_fold = np.zeros((self.n_splits, n_classes))
        groups_per_fold = defaultdict(set)

        if self.shuffle:
            rng.shuffle(y_counts_per_group)

        # Stable sort to keep shuffled order for groups with the same
        # class distribution variance
        sorted_groups_idx = np.argsort(-np.std(y_counts_per_group, axis=1),
                                       kind='mergesort')

        for group_idx in sorted_groups_idx:
            group_y_counts = y_counts_per_group[group_idx]
            best_fold = self._find_best_fold(
                y_counts_per_fold=y_counts_per_fold, y_cnt=y_cnt,
                group_y_counts=group_y_counts)
            y_counts_per_fold[best_fold] += group_y_counts
            groups_per_fold[best_fold].add(group_idx)
        for i in range(self.n_splits):
            test_indices = [idx for idx, group_idx in enumerate(groups_inv)
                            if group_idx in groups_per_fold[i]]
            yield test_indices
    def _find_best_fold(self, y_counts_per_fold, y_cnt, group_y_counts):
        best_fold = None
        min_eval = np.inf
        min_samples_in_fold = np.inf
        for i in range(self.n_splits):
            y_counts_per_fold[i] += group_y_counts
            # Summarise the distribution over classes in each proposed fold
            std_per_class = np.std(
                y_counts_per_fold / y_cnt.reshape(1, -1),
                axis=0)
            y_counts_per_fold[i] -= group_y_counts
            fold_eval = np.mean(std_per_class)
            samples_in_fold = np.sum(y_counts_per_fold[i])
            is_current_fold_better = (
                fold_eval < min_eval or
                np.isclose(fold_eval, min_eval)
                and samples_in_fold < min_samples_in_fold
            )
            if is_current_fold_better:
                min_eval = fold_eval
                min_samples_in_fold = samples_in_fold
                best_fold = i
        return best_fold
